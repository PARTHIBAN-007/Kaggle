# %% [markdown]
# <a href="https://www.kaggle.com/code/kparthiban007/gemini-mcq-generator?scriptVersionId=209198355" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="color:#fff; background-color:#f63343; font-size:25px; padding:10px; border-radius:25px; text-align:center;">
#     Gemini MCQ Generator
# </div>

# %%
import google.generativeai as genai
from kaggle_secrets import UserSecretsClient
import os
import time

user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("GEMINI_KEY")
genai.configure(api_key = api_key)
model = genai.GenerativeModel(model_name='gemini-1.5-flash-latest')

# %%
base_prompt = """
Based on the following prompt gemini ai will generate MCQ questions

- **User Input Details**:
    - Topic: {Topic}
    - Level : {Level}
    - Nquestions : {Nquestions}
    - Easy : {Easy}
    - Medium : {Medium} 
    - Hard : {Hard}


- **Output Format**:
    - Question
    - options
    - Difficulty level
    - Answer

**Output Example**:

    Question: What is 5 + 3?
    
    Options:
    a) 6
    b) 7
    c) 8
    d) 9
    Difficulty Level: Easy
    Answer: c) 8    

    
    

"""

# %%
def generate_prompt(Topic,Level,Nquestions,Easy,Medium,Hard):
    prompt = base_prompt.format(
        Topic = Topic,
        Level =  Level,
        Nquestions= Nquestions,
        Easy = Easy,
        Medium  = Medium, 
        Hard = Hard 
    )
    return prompt


def analyze_prompt(prompt_text):
    response = model.generate_content(prompt_text)
    return response.text


user_prompt = generate_prompt(
        Topic = "Artificial Intelligence",
        Level =  "Beginner",
        Nquestions= 10,
        Easy = 3,
        Medium  = 5, 
        Hard =  2 
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **Question 1:** What does AI stand for?
#
# **Options:**
# a) Artificial Intelligence
# b) Advanced Intelligence
# c) Applied Intelligence
# d) Automatic Intelligence
#
# **Difficulty Level:** Easy
# **Answer:** a) Artificial Intelligence
#
#
# **Question 2:** Which of the following is NOT a common application of AI?
#
# **Options:**
# a) Image recognition
# b) Natural language processing
# c) Manual data entry
# d) Self-driving cars
#
# **Difficulty Level:** Easy
# **Answer:** c) Manual data entry
#
#
# **Question 3:**  A system that learns from data without explicit programming is called:
#
# **Options:**
# a)  Traditional programming
# b)  Machine learning
# c)  Expert systems
# d)  Rule-based systems
#
# **Difficulty Level:** Easy
# **Answer:** b) Machine learning
#
#
# **Question 4:**  What is a neural network in the context of AI?
#
# **Options:**
# a) A type of computer network
# b) A computer system designed to mimic the human brain
# c) A complex algorithm for data sorting
# d) A type of programming language
#
# **Difficulty Level:** Medium
# **Answer:** b) A computer system designed to mimic the human brain
#
#
# **Question 5:**  Which of these is an example of supervised learning?
#
# **Options:**
# a) Training a robot to navigate a maze without prior knowledge
# b) Training a system to identify cats and dogs using labeled images
# c) Training a system to play a game through trial and error
# d) Generating new images based on existing ones
#
# **Difficulty Level:** Medium
# **Answer:** b) Training a system to identify cats and dogs using labeled images
#
#
# **Question 6:** The process of teaching a machine to learn from data without explicit instructions is known as:
#
# **Options:**
# a) Supervised Learning
# b) Unsupervised Learning
# c) Reinforcement Learning
# d) All of the above
#
# **Difficulty Level:** Medium
# **Answer:** b) Unsupervised Learning
#
#
# **Question 7:** What is a major concern regarding the development and use of AI?
#
# **Options:**
# a) Increased job opportunities
# b)  Improved healthcare outcomes
# c)  Potential for bias and discrimination
# d)  Reduced environmental impact
#
#
# **Difficulty Level:** Medium
# **Answer:** c) Potential for bias and discrimination
#
#
# **Question 8:**  Explain the difference between narrow AI and general AI.
#
# **Options:**
# a) Narrow AI can perform specific tasks, while general AI possesses human-level intelligence and can perform any intellectual task a human can.
# b) Narrow AI is more powerful than general AI.
# c) There is no difference between narrow AI and general AI.
# d) Narrow AI is slower than general AI.
#
# **Difficulty Level:** Medium
# **Answer:** a) Narrow AI can perform specific tasks, while general AI possesses human-level intelligence and can perform any intellectual task a human can.
#
#
# **Question 9:**  What is the "Turing Test"?
#
# **Options:**
# a) A test to measure the processing speed of a computer
# b) A test to determine if a machine can exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human
# c) A test to measure the memory capacity of a computer
# d) A test to determine the efficiency of a computer program
#
# **Difficulty Level:** Hard
# **Answer:** b) A test to determine if a machine can exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human
#
#
# **Question 10:** What is the concept of "Explainable AI" (XAI)?
#
# **Options:**
# a) AI systems that can explain their decision-making processes in a way that humans can understand.
# b) AI systems that can only process text data.
# c) AI systems that are designed for high-speed computation.
# d) AI systems that cannot be understood by humans.
#
# **Difficulty Level:** Hard
# **Answer:** a) AI systems that can explain their decision-making processes in a way that humans can understand.

# %%
user_prompt = generate_prompt(
        Topic = "Data Science",
        Level =  "Advanced",
        Nquestions= 10,
        Easy = 0,
        Medium  = 0, 
        Hard =  10
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **Question 1:**
#
# Which of the following techniques is NOT typically used for dimensionality reduction in high-dimensional data?
#
# a) Principal Component Analysis (PCA)
# b) t-distributed Stochastic Neighbor Embedding (t-SNE)
# c) K-Means Clustering
# d) Linear Discriminant Analysis (LDA)
#
# Difficulty Level: Hard
# Answer: c) K-Means Clustering
#
#
# **Question 2:**
#
# What is the primary drawback of using a simple linear regression model when the relationship between variables is non-linear?
#
# a) High variance
# b) High bias
# c) Overfitting
# d) Underfitting
#
# Difficulty Level: Hard
# Answer: b) High bias
#
#
# **Question 3:**
#
# In a Bayesian approach to machine learning, what does the posterior probability represent?
#
# a) The prior belief about the model parameters.
# b) The likelihood of observing the data given the model parameters.
# c) The updated belief about the model parameters after observing the data.
# d) The marginal likelihood of the data.
#
# Difficulty Level: Hard
# Answer: c) The updated belief about the model parameters after observing the data.
#
#
# **Question 4:**
#
# Which regularization technique adds a penalty term to the loss function proportional to the square of the magnitude of the model's weights?
#
# a) L1 regularization
# b) L2 regularization
# c) Dropout
# d) Early stopping
#
# Difficulty Level: Hard
# Answer: b) L2 regularization
#
#
# **Question 5:**
#
# Explain the bias-variance tradeoff in the context of model selection.  Which statement best describes it?
#
# a)  High bias models are always preferred because they generalize well.
# b) Low variance is preferred because it means the model's predictions are consistent across different datasets.
# c)  A good model balances the tradeoff between having low bias (accurate representation of the data) and low variance (consistent predictions).
# d) High variance models are preferred because they capture all the nuances in the training data.
#
# Difficulty Level: Hard
# Answer: c) A good model balances the tradeoff between having low bias (accurate representation of the data) and low variance (consistent predictions).
#
#
# **Question 6:**
#
# What is the purpose of a confusion matrix in evaluating a classification model?
#
# a) To calculate the mean squared error.
# b) To visualize the performance of the model across different classes.
# c) To determine the optimal learning rate.
# d) To select the best features for the model.
#
#
# Difficulty Level: Hard
# Answer: b) To visualize the performance of the model across different classes.
#
#
# **Question 7:**
#
# How does the ROC curve help in evaluating a classification model?
#
# a) It shows the relationship between precision and recall at various thresholds.
# b) It shows the relationship between true positive rate and false positive rate at various thresholds.
# c) It displays the accuracy of the model at different sample sizes.
# d) It visualizes the bias-variance trade-off.
#
# Difficulty Level: Hard
# Answer: b) It shows the relationship between true positive rate and false positive rate at various thresholds.
#
#
# **Question 8:**
#
# What is the key difference between supervised and unsupervised learning?
#
# a) Supervised learning uses labeled data, while unsupervised learning uses unlabeled data.
# b) Supervised learning predicts continuous values, while unsupervised learning predicts categorical values.
# c) Supervised learning uses only numerical data, while unsupervised learning can use both numerical and categorical data.
# d) Supervised learning is used for clustering, while unsupervised learning is used for classification.
#
#
# Difficulty Level: Hard
# Answer: a) Supervised learning uses labeled data, while unsupervised learning uses unlabeled data.
#
#
# **Question 9:**
#
# In the context of deep learning, what is backpropagation?
#
# a) A method for visualizing the network architecture.
# b) An algorithm for optimizing the hyperparameters.
# c) An algorithm for calculating gradients and updating model weights.
# d) A technique for data augmentation.
#
# Difficulty Level: Hard
# Answer: c) An algorithm for calculating gradients and updating model weights.
#
#
# **Question 10:**
#
# What is a common challenge associated with using Recurrent Neural Networks (RNNs) for long sequences?
#
# a) Overfitting
# b) Vanishing gradients
# c) High computational cost
# d) All of the above
#
# Difficulty Level: Hard
# Answer: d) All of the above

# %%
user_prompt = generate_prompt(
        Topic = "Tamil",
        Level =  "Advanced",
        Nquestions= 10,
        Easy = 3,
        Medium  = 5, 
        Hard =  2 
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **1. Question:**  Which Sangam poet is known for their extensive use of *akaval* meter and descriptions of nature?
#
#     **Options:**
#     a) Kapilar
#     b) Avvaiyar
#     c) Nakkeerar
#     d) Mangudi Marudanar
#     **Difficulty Level:** Medium
#     **Answer:** a) Kapilar
#
#
# **2. Question:**  Explain the significance of the *pattupattu* anthology in understanding Classical Tamil literature.
#
#     **Options:**
#     a) It showcases early forms of Tamil prose.
#     b) It primarily contains Jain philosophical texts.
#     c) It represents a crucial stage in the development of Tamil poetry, showcasing diverse themes and styles.
#     d) It is a collection of devotional hymns dedicated to Shiva.
#     **Difficulty Level:** Medium
#     **Answer:** c) It represents a crucial stage in the development of Tamil poetry, showcasing diverse themes and styles.
#
#
# **3. Question:** What is the meaning and historical context of the term "Ainkurunuru"?
#
#     **Options:**
#     a) Five hundred poems on love.
#     b) Five hundred verses of war poetry.
#     c) Five hundred short poems on miscellaneous themes.
#     d) Five hundred songs praising the Pandya kings.
#     **Difficulty Level:** Medium
#     **Answer:** c) Five hundred short poems on miscellaneous themes.
#
#
# **4. Question:**  Discuss the grammatical features unique to the Tamil language that differentiate it from other Dravidian languages.
#
#     **Options:**
#     a)  The use of postpositions instead of prepositions.
#     b)  The extensive use of case markers.
#     c)  The presence of a complex system of verb conjugations.
#     d) All of the above.
#     **Difficulty Level:** Hard
#     **Answer:** d) All of the above.
#
#
# **5. Question:** Translate the following Tamil sentence into English: "அறிவு உள்ளவன் அனைத்தையும் அடைவான்"
#
#     **Options:**
#     a) He who has knowledge will achieve everything.
#     b) Knowledge is power.
#     c) Wisdom is the path to success.
#     d)  A wise man conquers all.
#     **Difficulty Level:** Easy
#     **Answer:** a) He who has knowledge will achieve everything.
#
#
# **6. Question:**  Analyze the socio-political context reflected in the poems of the *Ettuthogai*.
#
#     **Options:**
#     a)  It mainly focuses on religious themes.
#     b)  It depicts a society largely untouched by social stratification.
#     c) It provides insights into the lives of various social classes and the political landscape of ancient Tamil Nadu.
#     d) It exclusively celebrates the heroism of kings and warriors.
#     **Difficulty Level:** Medium
#     **Answer:** c) It provides insights into the lives of various social classes and the political landscape of ancient Tamil Nadu.
#
#
# **7. Question:**  What are the key differences between the literary styles of the Sangam and post-Sangam periods in Tamil literature?
#
#     **Options:**
#     a)  The post-Sangam period showed a decline in literary quality.
#     b)  The Sangam period focused on secular themes, while the post-Sangam period emphasized religious themes.
#     c)  There were no significant stylistic differences between the two periods.
#     d)  The Sangam poetry is characterized by a more classical style, while the post-Sangam period saw the emergence of new genres and styles.
#     **Difficulty Level:** Hard
#     **Answer:** d) The Sangam poetry is characterized by a more classical style, while the post-Sangam period saw the emergence of new genres and styles.
#
#
# **8. Question:** Explain the concept of *uyir* and *mei* in Tamil grammar.
#
#     **Options:**
#     a)  They are two types of Tamil musical instruments.
#     b)  They represent the animate and inanimate aspects of nouns.
#     c)  They refer to the masculine and feminine genders.
#     d)  They are two different dialects of Tamil.
#     **Difficulty Level:** Medium
#     **Answer:** b) They represent the animate and inanimate aspects of nouns.
#
#
# **9. Question:**  Identify the literary significance of Thiruvalluvar's *Thirukkural*.
#
#     **Options:**
#     a) It is a collection of war poems.
#     b) It is a treatise on Tamil grammar.
#     c) It is a timeless collection of ethical and moral maxims.
#     d) It is a historical account of the Pandya dynasty.
#     **Difficulty Level:** Easy
#     **Answer:** c) It is a timeless collection of ethical and moral maxims.
#
#
# **10. Question:** Discuss the impact of Jainism and Buddhism on the development of Tamil literature.
#
#     **Options:**
#     a)  They had minimal influence on Tamil literature.
#     b)  They led to a decline in the quality of Tamil poetry.
#     c)  They significantly influenced the themes, styles, and genres of Tamil literature, particularly in the post-Sangam period.
#     d)  They completely replaced the existing Hindu traditions in Tamil literature.
#     **Difficulty Level:** Medium
#     **Answer:** c) They significantly influenced the themes, styles, and genres of Tamil literature, particularly in the post-Sangam period.
