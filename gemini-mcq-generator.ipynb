# %%
import google.generativeai as genai
from kaggle_secrets import UserSecretsClient
import os
import time

user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("GEMINI_KEY")
genai.configure(api_key = api_key)
model = genai.GenerativeModel(model_name='gemini-1.5-flash-latest')

# %%
base_prompt = """
Based on the following prompt gemini ai will generate MCQ questions

- **User Input Details**:
    - Topic: {Topic}
    - Level : {Level}
    - Nquestions : {Nquestions}
    - Easy : {Easy}
    - Medium : {Medium} 
    - Hard : {Hard}


- **Output Format**:
    - Question
    - options
    - Difficulty level
    - Answer

**Output Example**:

    Question: What is 5 + 3?
    
    Options:
    a) 6
    b) 7
    c) 8
    d) 9
    Difficulty Level: Easy
    Answer: c) 8    

    
    

"""

# %%
def generate_prompt(Topic,Level,Nquestions,Easy,Medium,Hard):
    prompt = base_prompt.format(
        Topic = Topic,
        Level =  Level,
        Nquestions= Nquestions,
        Easy = Easy,
        Medium  = Medium, 
        Hard = Hard 
    )
    return prompt


def analyze_prompt(prompt_text):
    response = model.generate_content(prompt_text)
    return response.text


user_prompt = generate_prompt(
        Topic = "Artificial Intelligence",
        Level =  "Beginner",
        Nquestions= 10,
        Easy = 3,
        Medium  = 5, 
        Hard =  2 
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **Question 1:** What does AI stand for?
#
# Options:
# a) Artificial Intelligence
# b) Advanced Intelligence
# c) Automated Intelligence
# d) Applied Information
#
# Difficulty Level: Easy
# Answer: a) Artificial Intelligence
#
#
# **Question 2:** Which of the following is NOT a common application of AI?
#
# Options:
# a) Spam filtering
# b) Medical diagnosis
# c) Manual data entry
# d) Self-driving cars
#
# Difficulty Level: Easy
# Answer: c) Manual data entry
#
#
# **Question 3:**  Machine learning is a subset of which broader field?
#
# Options:
# a) Biology
# b) Physics
# c) Artificial Intelligence
# d) Chemistry
#
# Difficulty Level: Easy
# Answer: c) Artificial Intelligence
#
#
# **Question 4:** What is a neural network in the context of AI?
#
# Options:
# a) A type of computer network
# b) A complex system of interconnected nodes
# c) A type of programming language
# d) A physical network of computers
#
# Difficulty Level: Medium
# Answer: b) A complex system of interconnected nodes
#
#
# **Question 5:** What is the purpose of a training dataset in machine learning?
#
# Options:
# a) To test the final model's performance
# b) To provide examples for the algorithm to learn from
# c) To store the final model's parameters
# d) To evaluate the algorithm's complexity
#
# Difficulty Level: Medium
# Answer: b) To provide examples for the algorithm to learn from
#
#
# **Question 6:**  Which of the following is a common challenge in developing AI systems?
#
# Options:
# a) Lack of data
# b) High computational cost
# c) Bias in data
# d) All of the above
#
# Difficulty Level: Medium
# Answer: d) All of the above
#
#
# **Question 7:** What is "overfitting" in machine learning?
#
# Options:
# a) When a model performs well on training data but poorly on new data
# b) When a model performs poorly on both training and new data
# c) When a model performs well on both training and new data
# d) When a model is too simple to capture the patterns in the data
#
# Difficulty Level: Medium
# Answer: a) When a model performs well on training data but poorly on new data
#
#
# **Question 8:** Explain the concept of "deep learning".
#
# Options:
# a)  A type of machine learning using multiple layers of neural networks.
# b)  A type of AI that focuses solely on image recognition.
# c)  A simplified approach to machine learning with fewer parameters.
# d)  A type of AI that operates solely on rule-based systems.
#
#
# Difficulty Level: Medium
# Answer: a) A type of machine learning using multiple layers of neural networks.
#
#
# **Question 9:** What is the Turing Test designed to evaluate?
#
# Options:
# a) The speed of a computer processor
# b) The ability of a machine to exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human
# c) The efficiency of a computer program
# d) The memory capacity of a computer
#
# Difficulty Level: Hard
# Answer: b) The ability of a machine to exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human
#
#
# **Question 10:** What is a potential ethical concern related to the use of AI?
#
# Options:
# a) Job displacement due to automation
# b) Algorithmic bias leading to unfair outcomes
# c) Privacy concerns related to data collection
# d) All of the above
#
# Difficulty Level: Hard
# Answer: d) All of the above

# %%
user_prompt = generate_prompt(
        Topic = "Data Science",
        Level =  "Advanced",
        Nquestions= 10,
        Easy = 0,
        Medium  = 0, 
        Hard =  10
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **Question 1:**
#
# Which of the following techniques is NOT typically used for dimensionality reduction in high-dimensional data?
#
# a) Principal Component Analysis (PCA)
# b) Linear Discriminant Analysis (LDA)
# c) t-distributed Stochastic Neighbor Embedding (t-SNE)
# d) K-Means Clustering
#
# Difficulty Level: Hard
# Answer: d) K-Means Clustering
#
#
# **Question 2:**
#
# In a Bayesian network, what does a directed edge between two nodes represent?
#
# a) Conditional dependence
# b) Unconditional independence
# c) Mutual exclusivity
# d) Correlation but not causation
#
# Difficulty Level: Hard
# Answer: a) Conditional dependence
#
#
# **Question 3:**
#
# What is the primary challenge addressed by techniques like gradient clipping and weight decay in training deep neural networks?
#
# a) Overfitting
# b) Underfitting
# c) Exploding/vanishing gradients
# d) Cold starts
#
# Difficulty Level: Hard
# Answer: c) Exploding/vanishing gradients
#
#
# **Question 4:**
#
# Which regularization technique adds a penalty term to the loss function proportional to the magnitude of the model's weights?
#
# a) Dropout
# b) L1 regularization
# c) L2 regularization
# d) Early stopping
#
# Difficulty Level: Hard
# Answer: c) L2 regularization
#
#
# **Question 5:**
#
# What is the key difference between a generative and discriminative model?
#
# a) Generative models learn the joint probability distribution, while discriminative models learn the conditional probability distribution.
# b) Generative models are faster to train, while discriminative models are more accurate.
# c) Generative models are used for classification, while discriminative models are used for regression.
# d) Generative models are simpler to implement, while discriminative models require more computational resources.
#
# Difficulty Level: Hard
# Answer: a) Generative models learn the joint probability distribution, while discriminative models learn the conditional probability distribution.
#
#
# **Question 6:**
#
# In reinforcement learning, what is the purpose of a reward function?
#
# a) To define the state space
# b) To define the action space
# c) To guide the agent towards optimal behavior
# d) To determine the learning rate
#
# Difficulty Level: Hard
# Answer: c) To guide the agent towards optimal behavior
#
#
# **Question 7:**
#
# What is a common problem encountered when using k-fold cross-validation with a limited dataset?
#
# a) Overfitting
# b) Underfitting
# c) Data leakage
# d) High variance in the performance estimates
#
# Difficulty Level: Hard
# Answer: d) High variance in the performance estimates
#
#
# **Question 8:**
#
# Which of the following is NOT a common metric for evaluating clustering algorithms?
#
# a) Silhouette score
# b) Davies-Bouldin index
# c) F1-score
# d) Calinski-Harabasz index
#
# Difficulty Level: Hard
# Answer: c) F1-score
#
#
# **Question 9:**
#
# What is the purpose of a confusion matrix in machine learning?
#
# a) To visualize the performance of a classification model
# b) To measure the distance between data points
# c) To select the optimal hyperparameters for a model
# d) To reduce the dimensionality of the data
#
# Difficulty Level: Hard
# Answer: a) To visualize the performance of a classification model
#
#
# **Question 10:**
#
# Explain the bias-variance tradeoff in the context of model generalization.  Which scenario would likely exhibit higher bias?
#
# a) A complex model trained on a large dataset
# b) A simple model trained on a small dataset
# c) A complex model trained on a small dataset
# d) A simple model trained on a large dataset
#
#
# Difficulty Level: Hard
# Answer: b) A simple model trained on a small dataset

# %%
user_prompt = generate_prompt(
        Topic = "Tamil",
        Level =  "Advanced",
        Nquestions= 10,
        Easy = 3,
        Medium  = 5, 
        Hard =  2 
    
)
result = analyze_prompt(user_prompt)
print("------------------------------\nResult:\n")
print(result)
# Out:
# ------------------------------
# Result:
#
# **1. Question:** Which Sangam poet is renowned for their evocative descriptions of nature and landscapes, often incorporating elements of the Tamil landscape and its flora and fauna?
#
# **Options:**
# a) Kapilar
# b) Avvaiyar
# c) Mangudi Maruthanar
# d) Kamban
#
# **Difficulty Level:** Medium
# **Answer:** a) Kapilar
#
#
# **2. Question:**  Explain the significance of the "Ainkurunuru" anthology within the context of Sangam literature and its contribution to understanding ancient Tamil society.
#
# **Options:**
# a) It primarily focuses on philosophical debates among scholars.
# b) It's a collection of short poems dealing with various aspects of love, war, and nature.
# c) It's a long epic poem narrating the history of the Chera dynasty.
# d) It primarily details the religious practices of ancient Tamils.
#
#
# **Difficulty Level:** Hard
# **Answer:** b) It's a collection of short poems dealing with various aspects of love, war, and nature.
#
#
# **3. Question:**  Identify the grammatical case used in the Tamil word  "வீட்டில்" (vēṭṭil) and explain its function in the sentence. (Note:  This requires knowledge of Tamil grammar).
#
# **Options:**
# a) Nominative
# b) Accusative
# c) Locative
# d) Instrumental
#
#
# **Difficulty Level:** Medium
# **Answer:** c) Locative
#
#
# **4. Question:**  What is the etymological origin and evolution of the Tamil word "சென்னை" (Chennai)?
#
# **Options:**
# a) Derived from Sanskrit, referring to a specific deity.
# b)  A Dravidian word predating recorded history, its meaning uncertain.
# c)  A corruption of a Telugu word indicating a geographical feature.
# d)  A combination of Tamil and Sanskrit roots.
#
#
# **Difficulty Level:** Hard
# **Answer:** c) A corruption of a Telugu word indicating a geographical feature.
#
#
# **5. Question:**  Translate the following Tamil sentence into English: "அறிவு உள்ளவன் அச்சமில்லாமல் இருப்பான்" (Arivu ullavan achamillaamal iruppān).
#
# **Options:**
# a)  The wise man fears nothing.
# b) The rich man lives happily.
# c) The brave man conquers all.
# d) The learned man speaks softly.
#
# **Difficulty Level:** Medium
# **Answer:** a) The wise man fears nothing.
#
#
# **6. Question:**  Which literary work is considered the Tamil equivalent of the Mahabharata, and who is its author?
#
# **Difficulty Level:** Easy
# **Answer:**  The Silapathikaram, Ilango Adigal
#
#
# **7. Question:** Discuss the influence of Jainism on Sangam literature, providing specific examples.
#
# **Difficulty Level:** Medium
# **Answer:** (This requires a detailed answer demonstrating knowledge of Jain influence on Sangam literature.  No single option can suffice.)
#
#
# **8. Question:** What are the key differences between the literary styles and themes found in the Ettuthogai and Pattupattu anthologies?
#
# **Difficulty Level:** Hard
# **Answer:** (This requires a comparative analysis of both anthologies and their distinct characteristics.)
#
#
# **9. Question:**  Translate the following Tamil proverb into English: "கல்வி அறிவுக்குப் பேர்" (Kalvi arivukkup pēr)
#
# **Options:**
# a) Knowledge is power.
# b) Education is the name of knowledge.
# c) Learning is a long journey.
# d) Wisdom comes with age.
#
# **Difficulty Level:** Easy
# **Answer:** b) Education is the name of knowledge.
#
#
# **10. Question:** Briefly explain the concept of "Agal Vilakkam" in Tamil literature and its symbolic significance.
#
# **Difficulty Level:** Medium
# **Answer:** (This requires an explanation of this literary/cultural concept. No single option can suffice).
